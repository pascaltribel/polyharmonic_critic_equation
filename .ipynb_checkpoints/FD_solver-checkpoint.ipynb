# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from tqdm.auto import tqdm

# %%
torch.set_default_device('cpu')
torch.set_default_dtype(torch.float64)

# %% [markdown]
# The PDE we are solving reads
# $$\alpha^2 y(\theta) = -\frac{\partial^2 y(\theta)}{\partial \theta},$$
# and we are working on a circle, which implies that $\theta = \theta + 2\pi$. For the rest, we fix an arbitrary value for $\alpha=1$.
# We train a PINN, that gets us a solution for the equation.  We want to build a Finite Differences solver that solves thhis equation. We fix a $\theta_0$ value.

# %%
alpha = torch.tensor(1.)
theta0 = torch.tensor(0.96303)
dtheta = torch.tensor(1e-5)
t_range = 8*torch.pi

# %%
thetas = torch.linspace(0, t_range, int(t_range/dtheta))

# %%
y = 1/torch.pi**0.5 * torch.cos(alpha*(thetas-theta0))

# %%
def fd_solver(y0, y1, dtheta, t):
    ys = [y0, y1]
    for _ in tqdm(range(int(t/dtheta)-2)):
        ys.append((-alpha**2)*ys[-1]*dtheta**2+2*ys[-1]-ys[-2])
    return torch.stack(ys)

# %%
y_hat = fd_solver(y[0], y[1], dtheta, t_range)
# Out:
#   0%|          | 0/2513272 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[272], line 1
# ----> 1 y_hat = fd_solver(y[0], y[1], dtheta, t_range)
#
# Cell In[271], line 4, in fd_solver(y0, y1, dtheta, t)
#       2 ys = [y0, y1]
#       3 for _ in tqdm(range(int(t/dtheta)-2)):
# ----> 4     ys.append((-alpha**2)*ys[-1]*dtheta**2+2*ys[-1]-ys[-2])
#       5 return torch.stack(ys)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/_tensor.py:44, in _handle_torch_function_and_wrap_type_error_to_not_implemented.<locals>.wrapped(self, *args, **kwargs)
#      42     sargs = self, *args
#      43     if has_torch_function(sargs):
# ---> 44         return handle_torch_function(wrapped, sargs, *sargs, **kwargs)
#      45     return f(self, *args, **kwargs)
#      46 except TypeError:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/overrides.py:1728, in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    1724 if _is_torch_function_mode_enabled():
#    1725     # if we're here, the mode must be set to a TorchFunctionStackMode
#    1726     # this unsets it and calls directly into TorchFunctionStackMode's torch function
#    1727     with _pop_mode_temporarily() as mode:
# -> 1728         result = mode.__torch_function__(public_api, types, args, kwargs)
#    1729     if result is not NotImplemented:
#    1730         return result
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/utils/_device.py:103, in DeviceContext.__torch_function__(self, func, types, args, kwargs)
#     101 if func in _device_constructors() and kwargs.get("device") is None:
#     102     kwargs["device"] = self.device
# --> 103 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/_tensor.py:45, in _handle_torch_function_and_wrap_type_error_to_not_implemented.<locals>.wrapped(self, *args, **kwargs)
#      43     if has_torch_function(sargs):
#      44         return handle_torch_function(wrapped, sargs, *sargs, **kwargs)
# ---> 45     return f(self, *args, **kwargs)
#      46 except TypeError:
#      47     return NotImplemented
#
# KeyboardInterrupt:

# %%
plt.plot(thetas.cpu(), y_hat.cpu(), label="yhat")
plt.plot(thetas.cpu(), y.cpu(), label="y")
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(thetas.cpu(), (y-y_hat).cpu())
plt.title("Error evolution")
plt.grid()
plt.show()

# %% [markdown]
# The local error is bounded to $O(d\theta^2)$. This truncation error (theoretically) should expand linearly with the number of steps, yielding a bound on the distribution of the error of $O(N d\theta^2) = O(t d\theta)$.

# %%
plt.figure(figsize=(10, 7))
plt.hist(torch.abs(y-y_hat).cpu(), bins=300)
plt.title(f"t*dtheta={t*dtheta}")
plt.grid()
plt.show()

# %% [markdown]
# Now, the question is to know if a PINN trained on data with the same discretization has the same distribution of error.
